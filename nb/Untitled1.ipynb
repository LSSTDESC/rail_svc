# %%
from rail_svc.db_oper import catalog_funcs
from rail.utils import catalog_utils
from rail_svc.db.session import get_session, init_db

# %%
init_db()

# %%
async with get_session() as the_session:
    await catalog_funcs.load_catalog_yaml(the_session, catalog_utils.DEFAULT_CATAlOG_TAG_FILE)
